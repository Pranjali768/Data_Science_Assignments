# %% [markdown]
# # Exercise 1: Prime Numbers

# %% [markdown]
# ##### Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num = int(input('Enter a number: '))

for x in range(2, num):
    if num % x == 0:
        print("number is not prime")
        break
    
else:
    print('number is prime')
# Out:
# Enter a number:  3
# number is prime

# %% [markdown]
# # Exercise 2: Product of Random Numbers

# %% [markdown]
# ##### Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
a = random.randint(1, 10)
b = random.randint(1,10)

print(f"Two random numbers are : {a} and {b}")

num1 = int(input('Enter the product of two numbers: '))

if num1 == a*b:
    print('your answer is correct!')
else:
    print('you have entered wrong answer')
# Out:
# Two random numbers are : 4 and 7
# Enter the product of two numbers:  28
# your answer is correct!!

# %% [markdown]
# # Exercise 3: Squares of Even/Odd Numbers

# %% [markdown]
# ##### Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
print('Squares of all even numbers: ')
for i in range(100, 201):
    if i % 2 == 0:
        print(f"square root of {i} ={i ** 2}")

print('\nSquares of all odd numbers: ')
for i in range(100,201):
    if i % 2 != 0:
        print(f"square root of {i} ={i ** 2}")
# Out:
# Squares of all even numbers:
# square root of 100 =10000
# square root of 102 =10404
# square root of 104 =10816
# square root of 106 =11236
# square root of 108 =11664
# square root of 110 =12100
# square root of 112 =12544
# square root of 114 =12996
# square root of 116 =13456
# square root of 118 =13924
# square root of 120 =14400
# square root of 122 =14884
# square root of 124 =15376
# square root of 126 =15876
# square root of 128 =16384
# square root of 130 =16900
# square root of 132 =17424
# square root of 134 =17956
# square root of 136 =18496
# square root of 138 =19044
# square root of 140 =19600
# square root of 142 =20164
# square root of 144 =20736
# square root of 146 =21316
# square root of 148 =21904
# square root of 150 =22500
# square root of 152 =23104
# square root of 154 =23716
# square root of 156 =24336
# square root of 158 =24964
# square root of 160 =25600
# square root of 162 =26244
# square root of 164 =26896
# square root of 166 =27556
# square root of 168 =28224
# square root of 170 =28900
# square root of 172 =29584
# square root of 174 =30276
# square root of 176 =30976
# square root of 178 =31684
# square root of 180 =32400
# square root of 182 =33124
# square root of 184 =33856
# square root of 186 =34596
# square root of 188 =35344
# square root of 190 =36100
# square root of 192 =36864
# square root of 194 =37636
# square root of 196 =38416
# square root of 198 =39204
# square root of 200 =40000
#
# Squares of all odd numbers:
# square root of 101 =10201
# square root of 103 =10609
# square root of 105 =11025
# square root of 107 =11449
# square root of 109 =11881
# square root of 111 =12321
# square root of 113 =12769
# square root of 115 =13225
# square root of 117 =13689
# square root of 119 =14161
# square root of 121 =14641
# square root of 123 =15129
# square root of 125 =15625
# square root of 127 =16129
# square root of 129 =16641
# square root of 131 =17161
# square root of 133 =17689
# square root of 135 =18225
# square root of 137 =18769
# square root of 139 =19321
# square root of 141 =19881
# square root of 143 =20449
# square root of 145 =21025
# square root of 147 =21609
# square root of 149 =22201
# square root of 151 =22801
# square root of 153 =23409
# square root of 155 =24025
# square root of 157 =24649
# square root of 159 =25281
# square root of 161 =25921
# square root of 163 =26569
# square root of 165 =27225
# square root of 167 =27889
# square root of 169 =28561
# square root of 171 =29241
# square root of 173 =29929
# square root of 175 =30625
# square root of 177 =31329
# square root of 179 =32041
# square root of 181 =32761
# square root of 183 =33489
# square root of 185 =34225
# square root of 187 =34969
# square root of 189 =35721
# square root of 191 =36481
# square root of 193 =37249
# square root of 195 =38025
# square root of 197 =38809
# square root of 199 =39601

# %% [markdown]
# # Exercise 4:
#
# ##### ✅ Problem Statement (Question): Hospital Billing System
# ##### A hospital charges its patients based on the following:
# ##### Room charges per day: ₹2,000
# ##### Doctor consultation fee (flat): ₹1,500
# ##### Lab test charges: Based on the number of tests taken. Each test costs ₹300
# ##### Medicine charges: Total cost of medicines provided
# ##### Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# ##### Write a Python program to calculate the final bill for a patient who:
# ##### Stayed for 4 days
# ##### Had 3 lab tests
# ##### Had medicine charges of ₹2,400

# %%
#Hospital charges
room_charge = 2000
doc_fee = 1500
lab_test_fee = 300 #per test
medicine = 2400

#patient details
days_stayed = 4
lab_tests = 3

#calculations
room_cost = room_charge * days_stayed
lab = lab_test_fee * lab_tests 

#total bill
tot_fee = room_cost + doc_fee + lab + medicine

#discount
if tot_fee > 10000:
    discount = 10/100 * tot_fee
    
else:
    discount = 0

#final bill
final_bill = tot_fee - discount

print('Hospital bill')
print(f"room charges: {room_cost}")
print(f"doctor fee: {doc_fee}")
print(f"lab test charges: {lab}")
print(f"medicine charges: {medicine}")
print(f"total bill: {tot_fee}")
print(f"discount: {discount}")
print(f"final bill: {final_bill}")
# Out:
# Hospital bill
# room charges: 8000
# doctor fee: 1500
# lab test charges: 900
# medicine charges: 2400
# total bill: 12800
# discount: 1280.0
# final bill: 11520.0
